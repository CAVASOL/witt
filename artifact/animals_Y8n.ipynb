# %% [markdown]
# <a href="https://colab.research.google.com/github/CAVASOL/witt/blob/main/artifact/animals_Y8n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ultralytics import YOLO

# %%
# %cd yolov5
# Out:
# /home/witt95573/animals_detection/yolov5

# %%
# %ls
# Out:
# CITATION.cff     __pycache__/   export.py         runs/           val.py
# CONTRIBUTING.md  benchmarks.py  hubconf.py        segment/        yolov5l.pt
# LICENSE          classify/      models/           train.py
# README.md        data/          pyproject.toml    tutorial.ipynb
# README.zh-CN.md  detect.py      requirements.txt  utils/

# %% [markdown]
# # Yolov8n_E30

# %% [markdown]
# ## Train

# %%
# !yolo train model=yolov8n.pt data=./data/animals.yaml epochs=30 imgsz=640 batch=32
# Out:
# New https://pypi.org/project/ultralytics/8.1.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.10 🚀 Python-3.8.10 torch-2.2.0+cu121 CUDA:0 (NVIDIA L4, 22491MiB)
# ...

# %%
model=YOLO('./runs/detect/Yolov8n_E30/weights/best.pt')

# %% [markdown]
# ## Val

# %%
# !yolo val model=./runs/detect/Yolov8n_E30_B32/weights/best.pt data=./data/animals.yaml
# Out:
# Ultralytics YOLOv8.1.10 🚀 Python-3.8.10 torch-2.2.0+cu121 CUDA:0 (NVIDIA L4, 22491MiB)
# Model summary (fused): 168 layers, 3017543 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/witt95573/animals_detection/yolo/test/labels.cache... 5337 i
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       5574       6235      0.646      0.617      0.638      0.533
#                   Bear       5574         41      0.473       0.39      0.401      0.365
#                   Bull       5574         22      0.411      0.318       0.25      0.189
#              Butterfly       5574        185      0.911      0.865       0.89      0.725
#                  Camel       5574         38      0.646      0.342      0.433      0.365
#                 Cattle       5574        206      0.929      0.191      0.624      0.536
#                Cheetah       5574          5      0.145        0.4      0.149      0.137
# ...

# %% [markdown]
# ## Predict

# %%
model.predict(source='/home/witt95573/animals_detection/yolo/sample', save=True, imgsz=640, conf=0.5)
# Out:
# image 1/10 /home/witt95573/animals_detection/yolo/sample/09fe1b842cb12ae3.jpg: 640x640 1 Monkey, 6.9ms
# image 2/10 /home/witt95573/animals_detection/yolo/sample/24f40361fb4211ea.jpg: 640x640 1 Turkey, 7.0ms
# image 3/10 /home/witt95573/animals_detection/yolo/sample/335aee45bfb3721d.jpg: 640x640 (no detections), 6.6ms
# image 4/10 /home/witt95573/animals_detection/yolo/sample/5de73c0a8a2f1ca9.jpg: 640x640 1 Rabbit, 6.4ms
# image 5/10 /home/witt95573/animals_detection/yolo/sample/626209c77c604300.jpg: 640x640 7 Fishs, 6.3ms
# image 6/10 /home/witt95573/animals_detection/yolo/sample/682b99230ab505da.jpg: 640x640 1 Frog, 6.3ms
# image 7/10 /home/witt95573/animals_detection/yolo/sample/89db149a2c4d564c.jpg: 640x640 1 Eagle, 6.9ms
# image 8/10 /home/witt95573/animals_detection/yolo/sample/acf2033ef487bb23.jpg: 640x640 1 Chicken, 6.3ms
# image 9/10 /home/witt95573/animals_detection/yolo/sample/dfd498d2190c5718.jpg: 640x640 1 Goldfish, 6.3ms
# ...

# %% [markdown]
# # Yolov8n_E50

# %% [markdown]
# ## Train

# %%
# !yolo train model=yolov8n.pt data=./data/animals.yaml epochs=50 imgsz=640 batch=32
# Out:
# New https://pypi.org/project/ultralytics/8.1.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.10 🚀 Python-3.8.10 torch-2.2.0+cu121 CUDA:0 (NVIDIA L4, 22491MiB)
# ...

# %% [markdown]
# ## Val

# %%
# !yolo val model=./runs/detect/Yolov8n_train2/weights/best.pt data=./data/animals.yaml
# Out:
# Ultralytics YOLOv8.1.10 🚀 Python-3.8.10 torch-2.2.0+cu121 CUDA:0 (NVIDIA L4, 22491MiB)
# Model summary (fused): 168 layers, 3017543 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/witt95573/animals_detection/yolo/test/labels.cache... 5337 i
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       5574       6235      0.709      0.596      0.657      0.548
#                   Bear       5574         41      0.495      0.334      0.368      0.339
#                   Bull       5574         22      0.199      0.136      0.152      0.127
#              Butterfly       5574        185      0.903      0.859      0.913      0.754
#                  Camel       5574         38      0.525      0.237      0.321      0.277
#                 Cattle       5574        206          1      0.159      0.555      0.465
#                Cheetah       5574          5      0.155        0.4      0.153      0.134
# ...

# %% [markdown]
# ## Predict

# %%
model=YOLO('./runs/detect/Yolov8n_train2/weights/best.pt')

# %%
model.predict(source='/home/witt95573/animals_detection/yolo/sample', save=True, imgsz=640, conf=0.5)
# Out:
# image 1/10 /home/witt95573/animals_detection/yolo/sample/09fe1b842cb12ae3.jpg: 320x320 1 Monkey, 6.8ms
# image 2/10 /home/witt95573/animals_detection/yolo/sample/24f40361fb4211ea.jpg: 320x320 1 Turkey, 7.3ms
# image 3/10 /home/witt95573/animals_detection/yolo/sample/335aee45bfb3721d.jpg: 320x320 1 Raccoon, 6.6ms
# image 4/10 /home/witt95573/animals_detection/yolo/sample/5de73c0a8a2f1ca9.jpg: 320x320 1 Rabbit, 6.6ms
# image 5/10 /home/witt95573/animals_detection/yolo/sample/626209c77c604300.jpg: 320x320 1 Fish, 6.5ms
# image 6/10 /home/witt95573/animals_detection/yolo/sample/682b99230ab505da.jpg: 320x320 1 Frog, 6.5ms
# image 7/10 /home/witt95573/animals_detection/yolo/sample/89db149a2c4d564c.jpg: 320x320 1 Eagle, 6.4ms
# image 8/10 /home/witt95573/animals_detection/yolo/sample/acf2033ef487bb23.jpg: 320x320 1 Chicken, 6.4ms
# image 9/10 /home/witt95573/animals_detection/yolo/sample/dfd498d2190c5718.jpg: 320x320 (no detections), 6.6ms
# ...

# %%
# !pwd
# Out:
# /home/witt95573/animals_detection/yolov5

# %% [markdown]
# ## Final training(Yolov8n_E50_augmented)

# %%
# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

# Train the model
results = model.train(data='./data/animals.yaml',
                      epochs=50,
                      imgsz=640,
                      batch=32,
                      close_mosaic=15,
                      augment=True, #
                      fliplr=0.7, #좌우반전
                      mosaic=0.5, #블러처리
                      degrees=0.1, #회전min/max rate
                     )
# Out:
# New https://pypi.org/project/ultralytics/8.1.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.10 🚀 Python-3.8.10 torch-2.2.0+cu121 CUDA:0 (NVIDIA L4, 22491MiB)
# ...

# %% [markdown]
# ## val

# %%
# !yolo val model=./runs/detect/Yolov8n_E50_augmented/weights/best.pt data=./data/animals.yaml
# Out:
# Ultralytics YOLOv8.1.10 🚀 Python-3.8.10 torch-2.2.0+cu121 CUDA:0 (NVIDIA L4, 22491MiB)
# Model summary (fused): 168 layers, 3016763 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/witt95573/animals_detection/yolo/test/labels.cache... 5177 i
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       5177       6010      0.648      0.629      0.665      0.554
#                   Bear       5177         41      0.506      0.401      0.395      0.349
#              Butterfly       5177        185      0.868      0.865      0.911      0.741
#                  Camel       5177         38      0.448      0.395      0.395       0.34
#                 Cattle       5177        206      0.825      0.252      0.566      0.483
#                Cheetah       5177          5      0.121        0.4      0.131      0.119
#                Chicken       5177        157      0.825      0.777      0.822      0.736
# ...

# %% [markdown]
# ## Predict

# %%
model=YOLO('./runs/detect/Yolov8n_E50_augmented/weights/best.pt')

# %%
model.predict(source='/home/witt95573/animals_detection/yolo/sample', save=True, imgsz=640, conf=0.5)
# Out:
# image 1/10 /home/witt95573/animals_detection/yolo/sample/09fe1b842cb12ae3.jpg: 640x640 1 Monkey, 6.9ms
# image 2/10 /home/witt95573/animals_detection/yolo/sample/24f40361fb4211ea.jpg: 640x640 1 Turkey, 7.3ms
# image 3/10 /home/witt95573/animals_detection/yolo/sample/335aee45bfb3721d.jpg: 640x640 1 Raccoon, 7.8ms
# image 4/10 /home/witt95573/animals_detection/yolo/sample/5de73c0a8a2f1ca9.jpg: 640x640 1 Rabbit, 6.9ms
# image 5/10 /home/witt95573/animals_detection/yolo/sample/626209c77c604300.jpg: 640x640 1 Fish, 6.7ms
# image 6/10 /home/witt95573/animals_detection/yolo/sample/682b99230ab505da.jpg: 640x640 1 Frog, 7.0ms
# image 7/10 /home/witt95573/animals_detection/yolo/sample/89db149a2c4d564c.jpg: 640x640 1 Eagle, 6.8ms
# image 8/10 /home/witt95573/animals_detection/yolo/sample/acf2033ef487bb23.jpg: 640x640 1 Chicken, 6.9ms
# image 9/10 /home/witt95573/animals_detection/yolo/sample/dfd498d2190c5718.jpg: 640x640 (no detections), 7.1ms
# ...

# %%
# !pwd
# Out:
# /home/witt95573/animals_detection/yolov5

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/detect/train3
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 8322), started 0:00:48 ago. (Use '!kill 8322' to kill it.)
#       <iframe id="tensorboard-frame-e3e70682c2094cac" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e3e70682c2094cac");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
